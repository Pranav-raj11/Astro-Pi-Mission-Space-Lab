# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Readings.csv')

# %%
data.head(1000)
# Out:
#      Counter                   Date/time   Latitude  Longitude  Temperature  \
# 0          1  2022-04-19 19:39:02.962324 -39.846273  81.964044      35.0092
# 1          2  2022-04-19 19:39:07.026540 -39.687475  82.226348      34.9914
# 2          3  2022-04-19 19:39:11.054875 -39.532677  82.479758      34.9558
# 3          4  2022-04-19 19:39:15.083144 -39.377216  82.732027      35.0092
# 4          5  2022-04-19 19:39:19.155543 -39.219412  82.985859      35.0803
# ..       ...                         ...        ...        ...          ...
# 995      996  2022-04-19 20:46:08.257579 -20.124953 -57.274016      34.8136
# 996      997  2022-04-19 20:46:12.285510 -20.320907 -57.108088      34.7069
# 997      998  2022-04-19 20:46:16.313645 -20.516670 -56.941696      34.7425
# 998      999  2022-04-19 20:46:20.385366 -20.714352 -56.773030      34.7780
# 999     1000  2022-04-19 20:46:24.412596 -20.909699 -56.605711      34.8136
#
#      Humidity   Pressure  Motion_Detected
# ...

# %%
data.tail()
# Out:
#       Counter                   Date/time   Latitude  Longitude  Temperature  \
# 2636     2637  2022-04-19 22:36:45.104713 -51.559982  -4.647829      35.0803
# 2637     2638  2022-04-19 22:36:49.132941 -51.532729  -4.251174      35.1514
# 2638     2639  2022-04-19 22:36:53.203858 -51.503705  -3.850736      35.0447
# 2639     2640  2022-04-19 22:36:57.276052 -51.473202  -3.450885      35.0625
# 2640     2641  2022-04-19 22:37:01.305196 -51.441561  -3.055748      35.0981
#
#       Humidity   Pressure  Motion_Detected
# 2636   29.1752  1006.0669            False
# 2637   29.4138  1006.0762            False
# 2638   29.2486  1006.0459            False
# 2639   29.1599  1006.0825            False
# 2640   29.4291  1006.0813            False

# %%
data.shape
# Out:
# (2641, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2641 entries, 0 to 2640
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Counter          2641 non-null   int64
#  1   Date/time        2641 non-null   object
#  2   Latitude         2641 non-null   float64
#  3   Longitude        2641 non-null   float64
#  4   Temperature      2641 non-null   float64
#  5   Humidity         2641 non-null   float64
#  6   Pressure         2641 non-null   float64
#  7   Motion_Detected  2641 non-null   bool
# dtypes: bool(1), float64(5), int64(1), object(1)
# memory usage: 147.1+ KB

# %%
data.dtypes
# Out:
# Counter              int64
# Date/time           object
# Latitude           float64
# Longitude          float64
# Temperature        float64
# Humidity           float64
# Pressure           float64
# Motion_Detected       bool
# dtype: object

# %%
data.describe()
# Out:
#            Counter     Latitude    Longitude  Temperature     Humidity  \
# count  2641.000000  2641.000000  2641.000000  2641.000000  2641.000000
# mean   1321.000000     1.939921     0.832893    34.818265    29.210876
# std     762.535354    34.595861   106.002895     0.170725     0.225726
# min       1.000000   -51.799219  -179.845745    34.333500    27.715800
# 25%     661.000000   -30.144231   -91.127811    34.724700    29.077300
# 50%    1321.000000     2.771364   -22.259706    34.795800    29.190500
# 75%    1981.000000    34.973000   104.946858    34.955800    29.328200
# max    2641.000000    51.799629   179.879657    35.240300    32.452000
#
#           Pressure
# count  2641.000000
# mean   1005.958022
# std       0.131909
# min    1005.637500
# 25%    1005.873800
# 50%    1005.964400
# 75%    1006.028800
# max    1006.239500

# %%
data.isnull().sum()
# Out:
# Counter            0
# Date/time          0
# Latitude           0
# Longitude          0
# Temperature        0
# Humidity           0
# Pressure           0
# Motion_Detected    0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2636    False
# 2637    False
# 2638    False
# 2639    False
# 2640    False
# Length: 2641, dtype: bool

# %%
data.columns
# Out:
# Index(['Counter', 'Date/time', 'Latitude', 'Longitude', 'Temperature',
#        'Humidity', 'Pressure', 'Motion_Detected'],
#       dtype='object')

# %%
sns.histplot(data['Latitude'], kde = True);

# %%
sns.histplot(data['Longitude'], kde = True);

# %%
sns.histplot(data['Temperature'], kde = True);

# %%
sns.histplot(data['Humidity'], kde = True);

# %%
sns.histplot(data['Pressure'], kde = True);

# %% [markdown]
# ### When there is motion:

# %%
motion = data[data["Motion_Detected"] == True]
motion.shape
# Out:
# (276, 8)

# %% [markdown]
# #### Max values:

# %%
motion["Humidity"].max()
# Out:
# 29.9126

# %%
motion["Temperature"].max()
# Out:
# 35.187

# %%
motion["Pressure"].max()
# Out:
# 1006.2288

# %% [markdown]
# #### Individual Graphs

# %%
sns.histplot(motion['Humidity'], kde = True);

# %%
sns.histplot(motion['Temperature'], kde = True);

# %%
sns.histplot(motion["Pressure"], kde = True)
# Out:
# <AxesSubplot:xlabel='Pressure', ylabel='Count'>

# %% [markdown]
# #### Relationship Graphs

# %%
sns.scatterplot(data = motion, x = "Temperature", y = "Humidity")
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Humidity'>

# %%
sns.scatterplot(data = data, x = "Humidity", y = "Pressure")
# Out:
# <AxesSubplot:xlabel='Humidity', ylabel='Pressure'>

# %%
sns.scatterplot(data = data, x = "Pressure", y = "Temperature")
# Out:
# <AxesSubplot:xlabel='Pressure', ylabel='Temperature'>

# %% [markdown]
# ### When there is no motion:

# %%
noMotion = data[data["Motion_Detected"] == False]
noMotion.shape
# Out:
# (2365, 8)

# %% [markdown]
# #### Max Values

# %%
noMotion["Temperature"].max()
# Out:
# 35.2403

# %%
noMotion["Humidity"].max()
# Out:
# 32.452

# %%
noMotion["Pressure"].max()
# Out:
# 1006.2395

# %% [markdown]
# #### Individual Graphs

# %%
sns.histplot(motion["Temperature"], kde = True)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Count'>

# %%
sns.histplot(motion["Humidity"], kde = True)
# Out:
# <AxesSubplot:xlabel='Humidity', ylabel='Count'>

# %%
sns.histplot(motion["Pressure"], kde = True)
# Out:
# <AxesSubplot:xlabel='Pressure', ylabel='Count'>
